# %%
# path to csv files in the cloud
PATH = "gs://tp3_inf8111"

# %% [markdown]
# # TP3 - Market Basket Analysis
# INF8111 - Fouille de données (Data Mining), Summer 2019 - Prof. Daniel Aloise
# ### Team Components
#     - Théo Moins
#     - Quentin Fournier
#
# **Authors**: Rodrigo Randel & Daniel Aloise

# %% [markdown]
# ## Market Basket Analysis
#
# Market Basket Analysis (MBA) is a data mining analytics technique to uncover associations between products or product grouping. By exploring interesting patterns from an extensive collection of data, MBA aims to understand/reveal customer purchase behaviors based upon the theory that if you purchased a certain set of products, then you are more (or less) likely to buy another group of products. In other words, MBA allows retailers to identify the relationship between the items that customers buy, revealing patterns of items often purchased together.
#
# A widely approach to explore these patterns is by constructing ***association rules*** such as:
# - **if** bought *ITEM_1* **then** will buy *ITEM_2* with **confidence** *X*.
#
# These associations do not have to be 1-to-1 rules. They can involve many items. For example, a person in a supermarket may add eggs to his/her cart, then an MBA application may suggest that the person will also buy some bread and/or flour:
#
# + **if** bought *EGGS* **then** will buy [*BREAD* with confidence *0.2*; *FLOUR* with confidence 0.05].
#
# However, if the person now decides to add flour to his/her cart, the new association rule could be as showing below, suggesting ingredients to make a cake.
#
# + **if** bought [*EGGS, FLOUR*] **then** will buy [*SUGGAR* with confidence 0.45; BAKING POWDER with confidence 0.12; *BREAD* with confidence *0.03*].
#
#
# There are many real scenarios where MBA plays a central role in data analysis, such as supermarket transactions, online orders or credit card history. Marketers may use these association rules to allocate correlated products close to each other on store shelves or make online suggestions so that customers buy more items. Some questions that an MBA can usually help retailers to answer are:
#
#     - What items are often purchased together?
#     - Given a basket, what items should be suggested?
#     - How should items be placed together on the shelves?
#
#
# ### Objective
#
# Your goal in this TP is to develop an MBA algorithm for revealing patterns by creating association rules in a big dataset with more than three millions supermarket transactions. However, mining association rules for large datasets is a very computationally intensive problem, which makes it almost impractical to perform it without a distributed system. Hence, to run your algorithm, you will have access to a distributed cloud computing cluster with hundreds of cores.
#
# To this end, a **MapReduce** algorithm will be implemented upon the [Apache Spark](http://spark.apache.org) framework, a fast cluster computing system. In a nutshell, Spark is an open source framework designed with a *scale-out* methodology which makes it a very powerful tool for programmers or application developers to perform a massive volume of computations and data processing in distributed environments. Sparks provides high-level APIs that make it easy to build parallel apps without needing to worry about how your code and data are parallelized/distributed thought the computing cluster. Spark does it all for you.
#
# The implementation will follow the Market Basket Analysis algorithm presented by Jongwook Woo and Yuhang Xu (2012). The image **workflow.svg** Illustrates the algorithm's workflow, and is to be used for consultation throughout this TP. The blue boxes are the ones where you must implement a method to perform a map or reduce function, and the grey boxes represent their expected output. **All these operations are explained in details in the following sections.**
#
# <!---
# # ![scale=0.5](workflow.svg "Algorithm Workflow")
# -->
#
# ## 1. Setting up Spark
#
# Spark runs on both Windows and UNIX-like systems (e.g., Linux, Mac OS). It's easy to run locally on one machine — all you need is to have Java installed on your system PATH, or the JAVA_HOME environment variable pointing to a Java installation. It is recommended that you have the **JDK v8** installed in your system. If you haven't, go to [Java's web page](https://www.oracle.com/technetwork/java/javase/downloads/jdk8-downloads-2133151.html) to download and install a Java Virtual Machine. Remember to set the environment variable JAVA_HOME if your installation does not do it automatically for you.
#
# The interface between Python and Spark is done through **PySpark**, which can be installed with *pip* as demonstrated below.
# <!--
# The first task is to get Spark up and running.
# 1. First, go to http://spark.apache.org/downloads
# 2. Select the newest Spark release and the pre-built package type
# 3. Click for download **spark-2.4.3-bin-hadoop2.7.tgz** and unzip it in any folder of your preference.
# 4. Next, export the following variables to link PYSPARK (Spark's python interface) to your python distribution
#     - export SPARK_HOME=/Users/rodrigorandel/Downloads/spark-2.4.3-bin-hadoop2.7
#     - export PYTHONPATH=$PYTHONPATH:$SPARK_HOME/python:$SPARK_HOME/python/lib/py4j-0.10.7-src.zip:$SPARK_HOME/python/lib/pyspark.zip
# -->

# %%
! pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/lib/spark/python
# Requirement already satisfied: py4j==0.10.7 in /opt/conda/anaconda/lib/python2.7/site-packages (from pyspark)
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### 1.1 Product Counting Example
#
# To test your installation and start to get familiarized with Spark, we will follow an example that counts how many times the products of a toy dataset were purchased.
#
# The main entry point to start programming with Spark is the [RDD API](https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD), an excellent Spark abstraction to work with the MapReduce framework.  RDD is a collection of elements partitioned across the nodes of the cluster that can operate in parallel. In other words, RDD is how Spark keeps your data ready to perform some function (e.g., a map or reduce function) in parallel. **Do not worry if this still sounds confusing, it will be clear once you start implementing**. However, it is part of this TP to study/consult the [Spark python API](https://spark.apache.org/docs/latest/api/python/) and learn how to use it. Some useful functions that the RDD API offers are:
#
# 1. **map**: return a new RDD by applying a function to each element of this RDD.
# 2. **flatMap**: return a new RDD by first applying a function to all elements of this RDD, and then flattening the results. **Should be used when each entry will yield more than one mapped element**
# 3. **reduce**: reduces the elements of this RDD using the specified commutative and associative binary operator.
# 4. **reduceByKey**: merge the values for each key using an associative and commutative reduce function
# 5. **groupByKey**: group the values for each key in the RDD into a single sequence
# 6. **collect**: return a list that contains all of the elements in this RDD. **Should not be used when working with a lot of data**
# 7. **sample**: return a sampled subset of this RDD
# 8. **count**: return the number of elements in this RDD.
# 9. **filter**: return a new RDD containing only the elements that satisfy a predicate.

# %%
from pyspark.sql import SparkSession

def map_to_product(row):
    """
    Map each transaction into a set of KEY-VALUE elements.
    The KEY is the word (product) itself and the VALUE is its number of apparitions.
    """
    products = [ r.encode('utf-8') for r in row.transaction.split(';')] # split products from the column transaction
    for p in products:
        yield (p, 1)

def reduce_product_by_key(value1, value2):
    "Reduce the mapped objects to unique words by merging (summing ) their values"
    return value1+value2

# Initializates a object of SparkSession class, main entry point to Spark's funcionalites
spark = SparkSession.builder.getOrCreate()
        
# Read a toy dataset
toy = spark.read.csv(PATH + '/toy.csv', header=True)
print("Toy dataset")
toy.show()

# Obtain a RDD object to call a map function
toy_rdd = toy.rdd
print("Toy dataframe as a RDD object (list of Row objects):\n\t", toy_rdd.collect())

# Map function to identify all products
toy_rdd = toy_rdd.flatMap(map_to_product)
print("\nMapped products:\n\t", toy_rdd.collect())

# Reduce function to merge values of elements that share the same KEY
toy_rdd = toy_rdd.reduceByKey(reduce_product_by_key)
print("\nReduced (merged) products:\n\t", toy_rdd.collect())

print("\nVisualizing as a dataframe:")
toy_rdd.toDF(["product", "count_product"]).show()
# Out:
# Toy dataset
# +--------+-----------+
# |order_id|transaction|
# +--------+-----------+
# |       1|      a;b;c|
# |       2|      a;b;d|
# |       3|        b;c|
# |       4|        b;c|
# +--------+-----------+
#
# ('Toy dataframe as a RDD object (list of Row objects):\n\t', [Row(order_id=u'1', transaction=u'a;b;c'), Row(order_id=u'2', transaction=u'a;b;d'), Row(order_id=u'3', transaction=u'b;c'), Row(order_id=u'4', transaction=u'b;c')])
# ('\nMapped products:\n\t', [('a', 1), ('b', 1), ('c', 1), ('a', 1), ('b', 1), ('d', 1), ('b', 1), ('c', 1), ('b', 1), ('c', 1)])
# ('\nReduced (merged) products:\n\t', [('a', 2), ('c', 3), ('b', 4), ('d', 1)])
#
# Visualizing as a dataframe:
# +-------+-------------+
# |product|count_product|
# +-------+-------------+
# |      a|            2|
# |      c|            3|
# |      b|            4|
# |      d|            1|
# +-------+-------------+

# %% [markdown]
# ### 1.2 Working the Spark's Dataframe
#
# In the example above, we briefly used a Spark's Dataframe class, but only to obtain an RDD object with ```toy.rdd``` and to print the data as a structured table with the ```show()``` function. However, [Dataframe](https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#) is a big part of the current Spark release and is built upon the RDD API. It is a distributed collection of rows under named columns, the same as a table in a relational database. Spark's Dataframe works similarily as [Pandas'](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html). In fact, we can export (obtain) a Spark's data frame to (from) a pandas' data frame with the function ```toPandas()``` (```spark.createDataFrame```).
#
# A central functionality of the data frame is to profit from the [Spark SQL](https://spark.apache.org/docs/latest/sql-programming-guide.html#sql), a module that allows SQL queries over structured data. For example, the same 'product counting example' could have been implemented as a sequence of SQL operations over the data:

# %%
import pyspark.sql.functions as f

# Creates a new column, products, with all products appering in each transaction
print('New column \'products\': exploding the transaction\'s products to a new row')
df_toy = toy.withColumn('products', f.explode(f.split(toy.transaction, ';')))
df_toy.show()

# Performs a select query and group rows by the product name, aggreagating by counting
print('Couting unique products:')
df_toy.select(df_toy.products)\
      .groupBy(df_toy.products)\
      .agg(f.count('products').alias('count_product'))\
      .sort('count_product', ascending=False)\
      .show()
# Out:
# New column 'products': exploding the transaction's products to a new row
# +--------+-----------+--------+
# |order_id|transaction|products|
# +--------+-----------+--------+
# |       1|      a;b;c|       a|
# |       1|      a;b;c|       b|
# |       1|      a;b;c|       c|
# |       2|      a;b;d|       a|
# |       2|      a;b;d|       b|
# |       2|      a;b;d|       d|
# |       3|        b;c|       b|
# |       3|        b;c|       c|
# |       4|        b;c|       b|
# |       4|        b;c|       c|
# +--------+-----------+--------+
#
# Couting unique products:
# +--------+-------------+
# |products|count_product|
# +--------+-------------+
# |       b|            4|
# |       c|            3|
# |       a|            2|
# |       d|            1|
# +--------+-------------+

# %% [markdown]
# Also, the same SQL operations performed above could have been done with a traditional SQL language query as showing below:

# %%
# Creates a relational table TOY in the Spark session
df_toy.createOrReplaceTempView("TOY")

spark.sql("SELECT t.products, COUNT(t.products) AS product_count"
          " FROM TOY t"
          " GROUP BY t.products"
          " ORDER BY product_count DESC").show()
# Out:
# +--------+-------------+
# |products|product_count|
# +--------+-------------+
# |       b|            4|
# |       c|            3|
# |       a|            2|
# |       d|            1|
# +--------+-------------+

# %% [markdown]
# These SQL concepts are being mentioned here because they will be useful to us during the TP, mainly in Section 3, to manipulate the supermarket data, which is structured in data frames. Then, if you are not familiar with SQL, it is recommended that you follow a [tutorial](https://www.w3schools.com/sql/) to understand the basics.
#
# ## 2. MBA Algorithm
#  The following sections explain how you should develop each step of the MapReduce algorithm for our supermarket application. Figure workflow.png illustrates each step of the algorithm.
#
# ### 2.1 Map to Patterns (10 points)
# For a given a set of transactions (i.e., the rows of our toy dataset), each transaction must be **mapped** into a set of *purchase patterns* found within the transaction. Formally, these patterns are subsets of products that represent a group of items bought together.
#
# For the MapReduce framework, each pattern must be created as a *KEY-VALUE* element, where they KEY can take the form of a singleton, a pair or a trio of products that are present in the transaction. More precisely, for each transaction, the mapping function must generate all possible **unique** subsets of size ONE, TWO or THREE.  The VALUE associated with each KEY is the number of times that the KEY appeared in the transaction (if we assume that no product appears more than once in the transaction, this value is always equal to one).
#
# Now, implement the  **map_to_patterns** function that receives a transaction (a row from the data frame) and returns the patterns found in the transaction. The mapped elements are a tuple (KEY, VALUE), where KEY is also a tuple of product names. It is crucial to notice that, since each entry (transaction) of the map function will **yield** more than one KEY-VALUE element, a *flatMap* must be invoked for this step.
#
# For the toy dataset, the expected output is similar to:
#
# <pre style="align:center; border:1px solid black;font-size: 9pt; line-height: 1.1; height: auto; width: 18em; padding-left:5px">
# <code>
# +---------------+-----------+
# |       patterns|occurrences|
# +---------------+-----------+
# |         ('a',)|          1|
# |     ('a', 'b')|          1|
# |('a', 'b', 'c')|          1|
# |     ('a', 'c')|          1|
# |         ('b',)|          1|
# |     ('b', 'c')|          1|
# |         ('c',)|          1|
# |         ('a',)|          1|
# |     ('a', 'b')|          1|
# |('a', 'b', 'd')|          1|
# |     ('a', 'd')|          1|
# |         ('b',)|          1|
# |     ('b', 'd')|          1|
# |         ('d',)|          1|
# |         ('b',)|          1|
# |     ('b', 'c')|          1|
# |         ('c',)|          1|
# |         ('b',)|          1|
# |     ('b', 'c')|          1|
# |         ('c',)|          1|
# +---------------+-----------+
# </code>
# </pre>

# %%
from itertools import chain, combinations

def format_tuples(pattern):
    """
    Used for visualizition.
    Transforms tuples to a string since Dataframe does not support column of tuples with different sizes
    (a,b,c) -> '(a,b,c)'
    """
    return (str(pattern[0]), str(pattern[1]))

def map_to_patterns(row):
    products = [r.encode('utf-8') for r in row.transaction.split(';')]
    iterable = chain(map(tuple, products), combinations(products, 2), combinations(products, 3))
    for p in iterable:
        yield (p, 1)

toy_rdd = toy.rdd
patterns_rdd = toy_rdd.flatMap(map_to_patterns)

# Output as dataframe
patterns_rdd.map(format_tuples).toDF(["patterns", "occurences"]).show()
# Out:
# +---------------+----------+
# |       patterns|occurences|
# +---------------+----------+
# |         ('a',)|         1|
# |         ('b',)|         1|
# |         ('c',)|         1|
# |     ('a', 'b')|         1|
# |     ('a', 'c')|         1|
# |     ('b', 'c')|         1|
# |('a', 'b', 'c')|         1|
# |         ('a',)|         1|
# |         ('b',)|         1|
# |         ('d',)|         1|
# |     ('a', 'b')|         1|
# |     ('a', 'd')|         1|
# |     ('b', 'd')|         1|
# |('a', 'b', 'd')|         1|
# |         ('b',)|         1|
# |         ('c',)|         1|
# |     ('b', 'c')|         1|
# |         ('b',)|         1|
# |         ('c',)|         1|
# |     ('b', 'c')|         1|
# +---------------+----------+

# %% [markdown]
# ### 2.2 Reduce patterns (5 points)
# Once different CPUs processed the transactions, a **reduce** function must take place to combine identical KEYS (the subset of products) and compute the total number of its occurrences in the entire dataset. In other words, this reduce procedure must sum the *VALUE* of each identical KEY.
#
# Create a **reduce_patterns** function below that must sum the VALUE of each pattern.
# For the toy dataset, the expected output is:
# <pre style="align:center; border:1px solid black;font-size: 9pt; line-height: 1.1; height: auto; width: 24em; padding-left:5px">
# <code>
# +---------------+--------------------+
# |       patterns|combined_occurrences|
# +---------------+--------------------+
# |         ('a',)|                   2|
# |     ('a', 'b')|                   2|
# |('a', 'b', 'c')|                   1|
# |     ('a', 'c')|                   1|
# |         ('b',)|                   4|
# |     ('b', 'c')|                   3|
# |         ('c',)|                   3|
# |('a', 'b', 'd')|                   1|
# |     ('a', 'd')|                   1|
# |     ('b', 'd')|                   1|
# |         ('d',)|                   1|
# +---------------+--------------------+
# </code>
# </pre>

# %%
def reduce_pattern_by_key(value1, value2):
    "Reduce the mapped objects to unique words by merging (summing ) their values"
    return value1 + value2

# Reduce function to merge values of elements that share the same KEY
combined_patterns_rdd = patterns_rdd.reduceByKey(reduce_pattern_by_key)

# Output as dataframe
combined_patterns_rdd.map(format_tuples).toDF(['patterns', 'combined_occurrences']).show()
# Out:
# +---------------+--------------------+
# |       patterns|combined_occurrences|
# +---------------+--------------------+
# |     ('b', 'c')|                   3|
# |         ('a',)|                   2|
# |         ('c',)|                   3|
# |('a', 'b', 'd')|                   1|
# |         ('b',)|                   4|
# |     ('a', 'c')|                   1|
# |         ('d',)|                   1|
# |     ('a', 'd')|                   1|
# |('a', 'b', 'c')|                   1|
# |     ('a', 'b')|                   2|
# |     ('b', 'd')|                   1|
# +---------------+--------------------+

# %% [markdown]
# ### 2.3 Map to subpatterns (15 points)
# Next, another **map** function should be applied to generate subpatterns. Once again, the subpatterns are KEY-VALUE elements, where the KEY is a subset of products as well. However, creating the subpattern's KEY is a different procedure. This time, the idea is to break down the list of products of each pattern (pattern KEY), remove one product at a time, and yield the resulting list as the new subpattern KEY.
#
# For example, for a given pattern $P$ with three products, $p_1, p_2 $ and $p_3$, three new subpatterns KEYs are going to be created: (i) remove $p_1$ and yield ($p_2, p_3$); (ii) remove $p_2$ and yield ($p_1,p_3$); and (iii) remove $p_3$ and yield ($p_1,p_2$).
#
# Additionally, the subpattern's VALUE structure will also be different. Instead of just single integer value as we had in the patterns, this time a *tuple* should be created for the subpattern VALUE. This tuple contains the product that was removed when yielding the KEY and the number of times the pattern appeared. For the example above, the values should be ($p_1,v$), ($p_2,v$) and ($p_3,v$), respectively, where $v$ is the VALUE of the pattern.
#
# The idea behind subpatterns is to create **rules** such as: when the products of KEY were bought, the item present in the VALUE was also bought *v* times. Furthermore, each pattern should also yield a subpattern where the KEY is the same list of products of the pattern, but the VALUE is a tuple with a null product (None) and the number of times the pattern appeared. This element will be useful to keep track of how many times such a pattern was found and later will be used to compute the confidence value when generating the association rules.
#
# Now, implement the  **map_to_subpatterns** function that receives a pattern and yields all found subpatterns. Once again, each entry (pattern) will generate more than one KEY-VALUE element, then a flatMap function must be called.
#
# For the toy dataset, the expected output is:
#
# <pre style="align:center; border:1px solid black;font-size: 9pt; line-height: 1.1; height: auto; width: 17em; padding-left:5px">
# <code>
# +---------------+---------+
# |    subpatterns|    rules|
# +---------------+---------+
# |         ('a',)|(None, 2)|
# |     ('a', 'b')|(None, 2)|
# |         ('b',)| ('a', 2)|
# |         ('a',)| ('b', 2)|
# |('a', 'b', 'c')|(None, 1)|
# |     ('b', 'c')| ('a', 1)|
# |     ('a', 'c')| ('b', 1)|
# |     ('a', 'b')| ('c', 1)|
# |     ('a', 'c')|(None, 1)|
# |         ('c',)| ('a', 1)|
# |         ('a',)| ('c', 1)|
# |         ('b',)|(None, 4)|
# |     ('b', 'c')|(None, 3)|
# |         ('c',)| ('b', 3)|
# |         ('b',)| ('c', 3)|
# |         ('c',)|(None, 3)|
# |('a', 'b', 'd')|(None, 1)|
# |     ('b', 'd')| ('a', 1)|
# |     ('a', 'd')| ('b', 1)|
# |     ('a', 'b')| ('d', 1)|
# |     ('a', 'd')|(None, 1)|
# |         ('d',)| ('a', 1)|
# |         ('a',)| ('d', 1)|
# |     ('b', 'd')|(None, 1)|
# |         ('d',)| ('b', 1)|
# |         ('b',)| ('d', 1)|
# |         ('d',)|(None, 1)|
# +---------------+---------+
# </code>
# </pre>

# %%
from copy import deepcopy

def map_to_subpatterns(pattern):
    p, v = pattern
    yield (p, ('None', v))
    if len(p) > 1:
        for _p1 in p:
            yield (tuple([_p for _p in p if _p != _p1]), (_p1, v))
            
subpatterns_rdd = combined_patterns_rdd.flatMap(map_to_subpatterns)

# Output as dataframe
subpatterns_rdd.map(format_tuples).toDF(['subpatterns', 'rules']).show(100)
# Out:
# +---------------+-----------+
# |    subpatterns|      rules|
# +---------------+-----------+
# |     ('b', 'c')|('None', 3)|
# |         ('c',)|   ('b', 3)|
# |         ('b',)|   ('c', 3)|
# |         ('a',)|('None', 2)|
# |         ('c',)|('None', 3)|
# |('a', 'b', 'd')|('None', 1)|
# |     ('b', 'd')|   ('a', 1)|
# |     ('a', 'd')|   ('b', 1)|
# |     ('a', 'b')|   ('d', 1)|
# |         ('b',)|('None', 4)|
# |     ('a', 'c')|('None', 1)|
# |         ('c',)|   ('a', 1)|
# |         ('a',)|   ('c', 1)|
# |         ('d',)|('None', 1)|
# |     ('a', 'd')|('None', 1)|
# |         ('d',)|   ('a', 1)|
# |         ('a',)|   ('d', 1)|
# |('a', 'b', 'c')|('None', 1)|
# |     ('b', 'c')|   ('a', 1)|
# |     ('a', 'c')|   ('b', 1)|
# |     ('a', 'b')|   ('c', 1)|
# |     ('a', 'b')|('None', 2)|
# |         ('b',)|   ('a', 2)|
# |         ('a',)|   ('b', 2)|
# |     ('b', 'd')|('None', 1)|
# |         ('d',)|   ('b', 1)|
# |         ('b',)|   ('d', 1)|
# +---------------+-----------+

# %% [markdown]
# ### 2.4 Reduce Subpatterns (5 points)
# Once again, a **reduce** function will be required to group all the subpatterns by their KEY. The objective of this reducing procedure is to create a list with all the **rules** that appeared by a KEY. Hence, the expected resulting of the reduce function is also a KEY-VALUE element, where the KEY is the subpattern's KEY, and the VALUE is a group containing all the VALUEs of the subpatterns that share the same KEY.
#
# For the toy dataset, the expected output is:
#
# <pre style="align:center; border:1px solid black;font-size: 9pt; line-height: 1.1; height: auto; width: 32em; padding-left:5px">
# <code>
# +-----------+--------------------------------------+
# |subpatterns|combined_rules                        |
# +-----------+--------------------------------------+
# |(a)        |((None, 2),('b', 2),('c', 1),('d', 1))|
# |(a,b)      |((None, 2),('c', 1),('d', 1))         |
# |(b)        |(('a', 2),(None, 4),('c', 3),('d', 1))|
# |(a,b,c)    |((None, 1))                           |
# |(b,c)      |(('a', 1),(None, 3))                  |
# |(a,c)      |(('b', 1),(None, 1))                  |
# |(c)        |(('a', 1),('b', 3),(None, 3))         |
# |(a,b,d)    |((None, 1))                           |
# |(b,d)      |(('a', 1),(None, 1))                  |
# |(a,d)      |(('b', 1),(None, 1))                  |
# |(d)        |(('a', 1),('b', 1),(None, 1))         |
# +-----------+--------------------------------------+
# </code>
# </pre>

# %%
combined_rules = subpatterns_rdd.groupByKey().mapValues(list)

# Output as dataframe
combined_rules.map(format_tuples).toDF(['subpatterns', 'combined_rules']).show(truncate=False)
# Out:
# +---------------+-------------------------------------------+
# |subpatterns    |combined_rules                             |
# +---------------+-------------------------------------------+
# |('b', 'c')     |[('None', 3), ('a', 1)]                    |
# |('a',)         |[('None', 2), ('c', 1), ('d', 1), ('b', 2)]|
# |('c',)         |[('b', 3), ('None', 3), ('a', 1)]          |
# |('a', 'b', 'd')|[('None', 1)]                              |
# |('b',)         |[('c', 3), ('None', 4), ('a', 2), ('d', 1)]|
# |('a', 'c')     |[('None', 1), ('b', 1)]                    |
# |('d',)         |[('None', 1), ('a', 1), ('b', 1)]          |
# |('a', 'd')     |[('b', 1), ('None', 1)]                    |
# |('a', 'b', 'c')|[('None', 1)]                              |
# |('a', 'b')     |[('d', 1), ('c', 1), ('None', 2)]          |
# |('b', 'd')     |[('a', 1), ('None', 1)]                    |
# +---------------+-------------------------------------------+

# %% [markdown]
# ## 2.5. Map to Association Rules (15 points)
# Finally, the last step of the algorithm is to create the association rules to perform the market basket analysis. The goal of this map function is to calculate the **confidence** level of buying a product, knowing that there is already a set of products in the basket. Thus, the KEY of the subpattern is the set of products placed in the basket and, for each product present in the list of rules, i.e., in the VALUE, the confidence can be calculated as:
#
# \begin{align*}
# \frac{\text{number of times the product was bought together with KEY }}{\text{number of times the KEY appeared}}
# \end{align*}
#
# For the example given in the Figure workflow, *coffee* was bought 20 times and, in 17 of them, *milk* was bought together. Then, the confidence level of buying *milk* knowing that *coffee* is in the basket is $\frac{17}{20} = 0.85$, which means that in 85% of the times the coffee was bought, milk was purchased as well.
#
# Implement the **map_to_assoc_rules** function that calculates the confidence level for each subpattern.
#
# For the toy dataset, the expected output is:
# <pre style="align:center; border:1px solid black;font-size: 9pt; line-height: 1.1; height: auto; width: 35em; padding-left:5px">
# <code>
# +---------------+---------------------------------------+
# |patterns       |association_rules                      |
# +---------------+---------------------------------------+
# |('a',)         |[('b', 1.0), ('c', 0.5), ('d', 0.5)]   |
# |('a', 'b')     |[('c', 0.5), ('d', 0.5)]               |
# |('b',)         |[('a', 0.5), ('c', 0.75), ('d', 0.25)] |
# |('a', 'b', 'c')|[]                                     |
# |('b', 'c')     |[('a', 0.3333333333333333)]            |
# |('a', 'c')     |[('b', 1.0)]                           |
# |('c',)         |[('a', 0.3333333333333333), ('b', 1.0)]|
# |('a', 'b', 'd')|[]                                     |
# |('b', 'd')     |[('a', 1.0)]                           |
# |('a', 'd')     |[('b', 1.0)]                           |
# |('d',)         |[('a', 1.0), ('b', 1.0)]               |
# +---------------+---------------------------------------+
# </code>
# </pre>

# %%
def map_to_assoc_rules(rule):
    pattern, ass = rule
    r, c = zip(*[(t[0], t[1]) for t in ass])
    mc = max(c)
    yield (pattern, [(_r, float(_c) / float(mc)) for _r, _c in zip(r, c) if "None" not in _r])

assoc_rules = combined_rules.flatMap(map_to_assoc_rules)

# Output as dataframe
assoc_rules.map(format_tuples).toDF(['patterns', 'association_rules']).show(truncate=False)
# Out:
# +---------------+---------------------------------------+
# |patterns       |association_rules                      |
# +---------------+---------------------------------------+
# |('b', 'c')     |[('a', 0.3333333333333333)]            |
# |('a',)         |[('c', 0.5), ('d', 0.5), ('b', 1.0)]   |
# |('c',)         |[('b', 1.0), ('a', 0.3333333333333333)]|
# |('a', 'b', 'd')|[]                                     |
# |('b',)         |[('c', 0.75), ('a', 0.5), ('d', 0.25)] |
# |('a', 'c')     |[('b', 1.0)]                           |
# |('d',)         |[('a', 1.0), ('b', 1.0)]               |
# |('a', 'd')     |[('b', 1.0)]                           |
# |('a', 'b', 'c')|[]                                     |
# |('a', 'b')     |[('d', 0.5), ('c', 0.5)]               |
# |('b', 'd')     |[('a', 1.0)]                           |
# +---------------+---------------------------------------+

# %% [markdown]
# ## 3. Instacart dataset
#
# With your MBA algorithm ready to be used, now it is time to work on the real dataset. For this part of the TP, download the [instacart](https://www.instacart.com/datasets/grocery-shopping-2017) dataset and read its [description](https://gist.github.com/jeremystan/c3b39d947d9b88b3ccff3147dbcf6c6b) to understand how the dataset is structured.
#
# Before applying the developed algorithm on the instacart dataset, you must first filter the transactions to be in the same format defined by your algorithm (one transaction per row). To manipulate the data, we can use Spark's data frame and the SQL module presented in Section 1.
#
# The following code cell uses the Spark SQL module to read the orders from the ``order_products__train.csv`` and the detailed information from ``orders.csv`` and ``products.csv`` to construct a data frame that contains a list of all products ever purchased by each user.

# %%
df_order_prod = spark.read.csv(PATH + '/order_products__train.csv', header=True, sep=',', inferSchema=True)
print('order_products__train.csv')
df_order_prod.show(5)

df_orders = spark.read.csv(PATH + '/orders.csv', header=True, sep=',', inferSchema=True)
print('orders.csv')
df_orders.show(5)

df_products = spark.read.csv(PATH + '/products.csv', header=True, sep=',', inferSchema=True)
print('products.csv')
df_products.show(5)

df_departments = spark.read.csv(PATH + '/departments.csv', header=True, sep=',', inferSchema=True)
print('departments.csv')
df_departments.show(5)


"""
List of products ever purchased by each user
"""
# USING SQL
df_order_prod.createOrReplaceTempView("order_prod") # creates table 'order_prod'
df_orders.createOrReplaceTempView("orders") # creates table 'orders'
df_products.createOrReplaceTempView("products") # creates table 'products'
df_departments.createOrReplaceTempView("departments") # creates table 'products'

spark.sql('SELECT o.user_id, COLLECT_LIST(p.product_name) AS products' 
               ' FROM orders o '
               ' INNER JOIN order_prod op ON op.order_id = o.order_id'
               ' INNER JOIN products p    ON op.product_id = p.product_id'
               ' GROUP BY user_id ORDER BY o.user_id').show(5, truncate=80)
# Out:
# order_products__train.csv
# +--------+----------+-----------------+---------+
# |order_id|product_id|add_to_cart_order|reordered|
# +--------+----------+-----------------+---------+
# |       1|     49302|                1|        1|
# |       1|     11109|                2|        1|
# |       1|     10246|                3|        0|
# |       1|     49683|                4|        0|
# |       1|     43633|                5|        1|
# +--------+----------+-----------------+---------+
# only showing top 5 rows
#
# orders.csv
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# |order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# | 2539329|      1|   prior|           1|        2|                8|                  null|
# | 2398795|      1|   prior|           2|        3|                7|                  15.0|
# |  473747|      1|   prior|           3|        3|               12|                  21.0|
# | 2254736|      1|   prior|           4|        4|                7|                  29.0|
# |  431534|      1|   prior|           5|        4|               15|                  28.0|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# only showing top 5 rows
#
# products.csv
# +----------+--------------------+--------+-------------+
# |product_id|        product_name|aisle_id|department_id|
# +----------+--------------------+--------+-------------+
# |         1|Chocolate Sandwic...|      61|           19|
# |         2|    All-Seasons Salt|     104|           13|
# |         3|Robust Golden Uns...|      94|            7|
# |         4|Smart Ones Classi...|      38|            1|
# |         5|Green Chile Anyti...|       5|           13|
# +----------+--------------------+--------+-------------+
# only showing top 5 rows
#
# departments.csv
# +-------------+----------+
# |department_id|department|
# +-------------+----------+
# |            1|    frozen|
# |            2|     other|
# |            3|    bakery|
# |            4|   produce|
# |            5|   alcohol|
# +-------------+----------+
# only showing top 5 rows
#
# +-------+--------------------------------------------------------------------------------+
# |user_id|                                                                        products|
# +-------+--------------------------------------------------------------------------------+
# |      1|[Soda, Organic String Cheese, 0% Greek Strained Yogurt, XL Pick-A-Size Paper ...|
# |      2|[Organic Roasted Turkey Breast, Gluten Free Whole Grain Bread, Plantain Chips...|
# |      5|[Organic Raw Agave Nectar, Organic Large Extra Fancy Fuji Apple, Sharp Chedda...|
# |      7|[Panama Peach Antioxidant Infusion, Antioxidant Infusions Beverage Malawi Man...|
# |      8|[Shallot, Organic SprouTofu Silken Tofu, Nutritional Yeast Seasoning, Organic...|
# +-------+--------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ### 3.1 Business Insights (15 points)
#
# Now, you are the data scientist. Considering only the orders from ``order_products__train.csv``, use of Spark SQL module, performing with SQL or data frame, to answer the following questions:
#
# 1. What are the top 10 products which have the highest probability of being reordered?
# 2. What are the busiest shopping hours for each department?
#     - Hint: plot a time series for each department
# 4. What is the size of the orders (basket size)?
#     - Hint: plot the basket size distribution

# %% [markdown]
# #### 1. Top 10 products which have the highest probability of being reordered:

# %%
spark.sql('SELECT products.product_name, SUM(reordered)/x.num as prob '
          'FROM ' 
              '(SELECT product_name, COUNT(*) AS num '
              'FROM order_prod JOIN products ON order_prod.product_id = products.product_id '
              'GROUP BY products.product_name) x ' 
          'JOIN products on x.product_name = products.product_name '
          'JOIN order_prod ON order_prod.product_id = products.product_id '
          'WHERE x.num > 40 '
          'GROUP BY products.product_name, x.num '
          'ORDER BY SUM(reordered)/x.num DESC').show(10, truncate=70)
# Out:
# +-------------------------------------+------------------+
# |                         product_name|              prob|
# +-------------------------------------+------------------+
# |                 2% Lactose Free Milk|0.9347826086956522|
# |                 Organic Low Fat Milk|0.9130434782608695|
# |            100% Florida Orange Juice|0.8983050847457628|
# |Original Sparkling Seltzer Water Cans|0.8888888888888888|
# |              Organic Spelt Tortillas|0.8888888888888888|
# |                               Banana|0.8841717398269785|
# |                   Petit Suisse Fruit|0.8833333333333333|
# |               Organic Lowfat 1% Milk|0.8819875776397516|
# |  Organic Lactose Free 1% Lowfat Milk|0.8810408921933085|
# |                       1% Lowfat Milk|0.8785249457700651|
# +-------------------------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# #### 2. Time series for each department:

# %%
import matplotlib.pyplot as plt

tables = spark.sql('SELECT department, order_hour_of_day,  COUNT(*) '
                      'FROM departments ' 
                      'INNER JOIN products ON departments.department_id = products.department_id '
                      'INNER JOIN order_prod ON order_prod.product_id = products.product_id '
                      'INNER JOIN orders ON orders.order_id = order_prod.order_id '
                      'GROUP BY departments.department, order_hour_of_day ORDER BY 3 DESC ').toPandas()

departments = df_departments.toPandas().department

resu = []

for i in departments:
    tmp = tables.where(tables["department"] == i).dropna()
    resu.append(tmp.sort_values(by="order_hour_of_day")["count(1)"])
    

resu = [list(r/sum(r)) for r in resu]

# Missing 0 value for bulb at 4 a.m
resu[9].insert(4,0)

x = list(range(24))

# %%
plt.figure(figsize=(10, 6), dpi=300)
plt.title('Time series of distribution of order for each department')
plt.xlabel('Hours of the day')
plt.ylabel('Probability')

for i, r in enumerate(resu):
    plt.plot(x, r, label=departments[i])
    plt.legend(loc='right', bbox_to_anchor=(1.25, 0.5))

plt.show()

# %% [markdown]
# #### 3. Basket size distribution:

# %%
basket_size = spark.sql('SELECT COUNT(*) as c '
                        'FROM order_prod '
                        'GROUP BY order_id ').toPandas()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6), dpi=300)
sns.distplot(basket_size, kde_kws={"gridsize":1000})
plt.xlim((1,100))
plt.title("Distribtion of basket's size")
plt.xlabel("Basket size")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# ### 3.2 Run MBA for the training set (10 points)
#
# Using the orders from the ``order_products__train.csv``, create a data frame where each row contain just one column, the transaction, with the list of purchased products. For this task, you do not have to query for the product names to run the MBA algorithm. You can assume that the product name is its id. This can accelerate the algorithm since the product names can be quite big.
#
# You must report the time spent to perform this task.

# %%
import itertools 

def pretty_print_asso(dataframe):
    for d in dataframe:
        pattern = " + ".join(d.patterns[2:-2].replace("'", '').split(", "))
        counter = 0
        for a in itertools.islice(d.association_rules[2:].split('), ('), 5):
            if a:
                counter += 1
                reg = a.split(', ')
                association = ' + '.join(reg[:-1]).replace("'", '').replace('"', '')
                print("{} -> {} ({})".format(pattern, association, reg[-1]))
        if counter > 10:
            break

# %%
# redefine map_to_patterns to take a list as input
def map_to_patterns_list(row):
    products = [r.encode('utf-8') for r in row.transaction]
    prod_tuple = [(p, ) for p in products]
    iterable = chain(prod_tuple, combinations(products, 2),
                     combinations(products, 3))
    for p in iterable:
        yield (p, 1)

# %%
train_rdd = spark.sql(
    'SELECT order_id, COLLECT_LIST(product_name) as transaction '
    'FROM order_prod JOIN products ON order_prod.product_id = products.product_id '
    'GROUP BY order_id').rdd

train_rdd.toDF(["order_id", "transaction"]).show(20, truncate=80)
# Out:
# +--------+--------------------------------------------------------------------------------+
# |order_id|                                                                     transaction|
# +--------+--------------------------------------------------------------------------------+
# |    1342|[Bag of Organic Bananas, Seedless Cucumbers, Organic Mandarins, Organic Straw...|
# |    1591|[Cracked Wheat, Organic Greek Whole Milk Blended Vanilla Bean Yogurt, Navel O...|
# |    4519|            [Beet Apple Carrot Lemon Ginger Organic Cold Pressed Juice Beverage]|
# |    4935|                                                                         [Vodka]|
# |    6357|[Fresh Mozzarella Ball, Grated Parmesan, Organic Basil, Provolone, Gala Apple...|
# |   10362|[Crinkle Cut French Fries, The Ultimate Beefless Burger, Original Tofurky Del...|
# |   19204|[Lemon Lime Thirst Quencher, Electrolyte Enhanced Water, High Efficiency Comp...|
# |   29601|[Toasted Coconut Almondmilk Blend, Skillet Refried Red Beans Sautéed With Oni...|
# |   31035|[Bag of Organic Bananas, Organic Navel Orange, Organic Cripps Pink Apples, Or...|
# |   40011|[Sea Salt Macadamias, Natural Calm Magnesium Supplement Raspberry Lemon Flavo...|
# |   46266|[Organic Uncured Sliced Black Forest Ham, Organic Low Fat Cottage Cheese, Org...|
# |   51607|[Major Dickason's Blend Dark Roast K-Cups, Classic K-Cup Pods Hot Cocoa, Pike...|
# |   58797|[Bag of Organic Bananas, Mini Seedless Watermelon Pack, Organic Broccoli, See...|
# |   61793|[Raspberries, Natural Spring Water, Green Seedless Grapes, Mixed Fruit Fruit ...|
# |   67089|[Banana, Organic Avocado, Almond Breeze Original Almond Milk, Feta Cheese Cru...|
# |   70863|[Bathroom Tissue, Double Rolls, 3-Ply, Pane Turano Italian Bread, Presliced E...|
# |   88674|[Unsweetened Almond Milk, Everything Bagels, Rosemary, Organic Coconut Milk, ...|
# |   91937|[No. 485 Gin, Traditional New England Clam Chowder Soup, Apple Juice, Montere...|
# |   92317|[Banana, Indian Mattar Tofu, Harvest Casserole Bowls, Brown Rice & Vegetables...|
# |   99621|[Organic Basil, Fresh Basil, Fennel, Okra, Organic Garlic, Lemon Sorbet, Orga...|
# +--------+--------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# %%time

train_rdd = train_rdd.flatMap(map_to_patterns_list)
train_rdd = train_rdd.reduceByKey(reduce_pattern_by_key)
train_rdd = train_rdd.flatMap(map_to_subpatterns)
train_rdd = train_rdd.groupByKey().mapValues(list)
train_rdd = train_rdd.flatMap(map_to_assoc_rules)

df = train_rdd.map(format_tuples).toDF(['patterns', 'association_rules']).take(100)
pretty_print_asso(df)
# Out:
# Premium Plastic Wrap + Cantina Traditional Tortilla Chips -> All Natural Red Tomato Mild Salsa Mexican with Green Chile & Cilantro (1.0)
# Premium Plastic Wrap + Cantina Traditional Tortilla Chips -> Original Strawberry Gelatin Snacks (1.0)
# Premium Plastic Wrap + Cantina Traditional Tortilla Chips -> Family Size Hearts of Romaine (1.0)
# Premium Plastic Wrap + Cantina Traditional Tortilla Chips -> Banana (1.0)
# Premium Plastic Wrap + Cantina Traditional Tortilla Chips -> Cool Mint Chocolate (1.0)
# Organic Plain Nonfat Greek Yogurt + Organic Jellied Cranberry Sauce -> Organic Beef Broth (1.0)
# Organic Plain Nonfat Greek Yogurt + Organic Jellied Cranberry Sauce -> Skim Milk (1.0)
# Organic Plain Nonfat Greek Yogurt + Organic Jellied Cranberry Sauce -> Organic Low Sodium Chicken Broth (1.0)
# Organic Plain Nonfat Greek Yogurt + Organic Jellied Cranberry Sauce -> Seedless Red Grapes (1.0)
# Organic Plain Nonfat Greek Yogurt + Organic Jellied Cranberry Sauce -> Green Peas No Salt Added (1.0)
# Organic Red Onion + Chopped Garlic In Water -> Organic Pancake Syrup (1.0)
# Organic Red Onion + Chopped Garlic In Water -> Organic Egg Whites (1.0)
# Organic Red Onion + Chopped Garlic In Water -> Organic Unsalted Butter (1.0)
# Organic Red Onion + Chopped Garlic In Water -> Feta Cheese Crumbles (1.0)
# Organic Red Onion + Chopped Garlic In Water -> Asparagus (1.0)
# Sweet White Corn + Lime -> Light & Lean Spinach Lasagna (1.0)
# Sweet White Corn + Lime -> Hearts Of Romaine (1.0)
# Sweet White Corn + Lime -> Bunched Cilantro (1.0)
# Sweet White Corn + Lime -> Banana (1.0)
# Sweet White Corn + Lime -> Organic Gluten Free Non-Dairy Beans & Rice Burrito (1.0)
# Leek + Garlic Couscous -> Grapefruit Sparkling Water (1.0)
# Leek + Garlic Couscous -> Extra Crunchy Peanut Butter (1.0)
# Leek + Garlic Couscous -> Original Wheat Thins (1.0)
# Leek + Garlic Couscous -> Classic Hummus Family Size (1.0)
# Leek + Garlic Couscous -> 93% Lean Ground Turkey (1.0)
# Rice Krispies Treats Original Crispy Marshmallow Squares + French Roast + Dark Roast K-Cups -> Nonfat Probiotic Drinks (1.0)
# Rice Krispies Treats Original Crispy Marshmallow Squares + French Roast + Dark Roast K-Cups -> Orange Juice (1.0)
# Rice Krispies Treats Original Crispy Marshmallow Squares + French Roast + Dark Roast K-Cups -> Slim Can Pink Grapefruit Natural Mineral Water (1.0)
# Rice Krispies Treats Original Crispy Marshmallow Squares + French Roast + Dark Roast K-Cups -> Breakfast Blend Medium Keurig Brewed K-Cups Ground Coffee (1.0)
# Rice Krispies Treats Original Crispy Marshmallow Squares + French Roast + Dark Roast K-Cups -> One Ply Choose A Size Big Roll Paper Towel Rolls (1.0)
# Shredded Almond Mozzarella Cheese + Gluten Free Foods Granola -> Non Fat Plain Goat Yogurt (1.0)
# Shredded Almond Mozzarella Cheese + Gluten Free Foods Granola -> Mild Guacamole (1.0)
# Shredded Almond Mozzarella Cheese + Gluten Free Foods Granola -> Organic Large Brown Grade AA Cage Free Eggs (1.0)
# Shredded Almond Mozzarella Cheese + Gluten Free Foods Granola -> Hass Avocado (1.0)
# Shredded Almond Mozzarella Cheese + Gluten Free Foods Granola -> Organic Good Seed Bread (1.0)
# 2% Reduced Fat DHA Omega-3 Reduced Fat Milk + Black Plum -> Crackers Cheddar Bunnies Snack Packs (0.5)
# 2% Reduced Fat DHA Omega-3 Reduced Fat Milk + Black Plum -> Natural Premium Coconut Water (0.5)
# 2% Reduced Fat DHA Omega-3 Reduced Fat Milk + Black Plum -> Organic Bunny Fruit Snacks Berry Patch (0.5)
# 2% Reduced Fat DHA Omega-3 Reduced Fat Milk + Black Plum -> Organic American Cheese Singles (0.5)
# 2% Reduced Fat DHA Omega-3 Reduced Fat Milk + Black Plum -> Gluten Free SpongeBob Spinach Littles (0.5)
# Pink Grapefruit + Wieners -> Black Plum (1.0)
# Pink Grapefruit + Wieners -> Light Mozarella String Cheese (1.0)
# Pink Grapefruit + Wieners -> Original Cooking Spray (1.0)
# Pink Grapefruit + Wieners -> Limes (1.0)
# Pink Grapefruit + Wieners -> Decadence Biscotti (1.0)
# CPU times: user 104 ms, sys: 28 ms, total: 132 ms
# Wall time: 3min 7s

# %% [markdown]
# ## 3.3 Run MBA for your custom dataset (25 points)
#
# As you probably noticed, even for a not so large data set (the training file has only 131209 orders), the MBA algorithm is computationally expensive. For that reason, this time, we will repeat the process, but now using the Google Cloud Platform (GCP) to create a large computer cluster. All the instructions for creating a computing cluster with spark and how to submit a job will be explained in both sessions of the laboratory. In any case, you should read the instructions given in the ``instruction_gcp.pdf``.
#
# This time, we will work with the ``order_products__prior.csv`` file, which contains more than 3M orders.
#
# **EXPECTED OUTPUT**
#
# After you ran the MBA for the larger collection of orders, randomly select 10 products purchased in ``order_products__prior`` and print the association rules associated to those products when the product is alone in the basket. **This time,  the products' name should be printed, not its ID. You can still perform the MBA using the IDs, but this last print must show the names. **
#
# Report the execution time.

# %%
df_order_prod_prior = spark.read.csv(PATH + '/order_products__prior.csv', header=True, sep=',', inferSchema=True)
df_order_prod_prior.createOrReplaceTempView("order_prod_prior")

prior_rdd = spark.sql(
    'SELECT order_id, COLLECT_LIST(product_name) as transaction '
    'FROM order_prod_prior JOIN products ON order_prod_prior.product_id = products.product_id '
    'GROUP BY order_id').rdd

# %%
# %%time

prior_rdd = prior_rdd.flatMap(map_to_patterns_list)
prior_rdd = prior_rdd.reduceByKey(reduce_pattern_by_key)
prior_rdd = prior_rdd.flatMap(map_to_subpatterns)
prior_rdd = prior_rdd.groupByKey().mapValues(list)
prior_rdd = prior_rdd.flatMap(map_to_assoc_rules)

df = prior_rdd.filter(lambda x: len(x[0])==1).map(format_tuples).toDF(['patterns', 'association_rules']).take(100)
pretty_print_asso(df)
# Out:
# Organic Red Potatoes -> Tilapia Fillet (0.00023391812865497077)
# Organic Red Potatoes -> Smoked Turkey Breast Slices (0.0029239766081871343)
# Organic Red Potatoes -> Classic Side Sliced Hot Dog Buns (0.00023391812865497077)
# Organic Red Potatoes -> Spaghetti (0.004678362573099415)
# Organic Red Potatoes -> Organic Very Raw Honey (0.00046783625730994154)
# Cheese Danish -> Cube Stuffing (0.005154639175257732)
# Cheese Danish -> 12 Grain Bread (0.005154639175257732)
# Cheese Danish -> Garlic Texas Toast (0.005154639175257732)
# Cheese Danish -> Teriyaki Noodles Asian Sides (0.005154639175257732)
# Cheese Danish -> Pizzeria Style Classic Crust Pepperoni Pizza (0.005154639175257732)
# Mara Natha Organic Peanut Butter Creamy -> Sour Batard (0.0005793742757821553)
# Mara Natha Organic Peanut Butter Creamy -> Whole Natural Value Pack Almonds (0.0005793742757821553)
# Mara Natha Organic Peanut Butter Creamy -> Strawberry Rhubarb Yogurt (0.0005793742757821553)
# Mara Natha Organic Peanut Butter Creamy -> Coconut Almond Creamer Blend (0.0005793742757821553)
# Mara Natha Organic Peanut Butter Creamy -> Ravioli + Spinach & Cheese (0.0028968713789107765)
# Normal Perfect C Serum -> Organic Diced Tomatoes (0.08333333333333333)
# Normal Perfect C Serum -> Loofah Sponges (0.08333333333333333)
# Normal Perfect C Serum -> Garbage Disposal Freshner & Cleaner + Thyme with Fig Leaf (0.08333333333333333)
# Normal Perfect C Serum -> Organic Mini Sandwich Crackers Cheddar Cheese (0.08333333333333333)
# Normal Perfect C Serum -> Dairy Free Gluten Free Cookie Dough Coconut Milk Frozen Dessert (0.08333333333333333)
# Power & Fresh Cling Gel Ocean Fresh Scent Toilet Bowl Cleaner -> Fresh Lavender Super Odor Neutralizer Long Last Adjustable Air Freshener (0.009433962264150943)
# Power & Fresh Cling Gel Ocean Fresh Scent Toilet Bowl Cleaner -> Classic Crust Pepperoni Pizza (0.009433962264150943)
# Power & Fresh Cling Gel Ocean Fresh Scent Toilet Bowl Cleaner -> Deli Fresh Rotisserie Seasoned Chicken Breast (0.009433962264150943)
# Power & Fresh Cling Gel Ocean Fresh Scent Toilet Bowl Cleaner -> Crumbled Feta Cheese + Fat Free (0.009433962264150943)
# All Natural Mint Cilantro Chili Sauce -> Diced Red Onions (0.018518518518518517)
# All Natural Mint Cilantro Chili Sauce -> Organic Unsweetened Black Tea (0.018518518518518517)
# 8 Piece Grilled Chicken -> Roasted Turkey Breast (0.0625)
# 8 Piece Grilled Chicken -> Designer Paper Plates 7 In (0.0625)
# 8 Piece Grilled Chicken -> 8.5 Microwavable Cut Resistant Plates (0.0625)
# 8 Piece Grilled Chicken -> Shredded Sharp Cheddar Cheese (0.0625)
# 8 Piece Grilled Chicken -> Roasted Garlic Hummus (0.0625)
# Free & Clear Bleach -> Organic Classic Rich Crackers (0.0011061946902654867)
# Free & Clear Bleach -> Creamy Almond Butter (0.0022123893805309734)
# Free & Clear Bleach -> Milk Chocolate Nuggets (0.0011061946902654867)
# Free & Clear Bleach -> Organic Extra Large Grade AA Brown Eggs (0.0011061946902654867)
# Free & Clear Bleach -> Zero Soda (0.0005530973451327434)
# French Style Cut Green Beans -> Lemons (0.020833333333333332)
# French Style Cut Green Beans -> Chili With Beans (0.020833333333333332)
# French Style Cut Green Beans -> Kids Soft and Chewy Candy (0.020833333333333332)
# French Style Cut Green Beans -> 100% Oatnut Bread (0.041666666666666664)
# French Style Cut Green Beans -> Cauliflower (0.020833333333333332)
# Whole Coriander -> Sweet Onion (0.08)
# Whole Coriander -> Organic Fava Beans (0.04)
# Whole Coriander -> Concord Grape Jam (0.04)
# Whole Coriander -> Yamaimo Soba Buckwheat Noodles (0.04)
# Whole Coriander -> Distilled White Vinegar (0.04)
# Reeses Pieces Bag" -> Original 100% Pure No Pulp Orange Juice (0.2)
# Reeses Pieces Bag" -> Chicken Chow Mein (0.011764705882352941)
# Reeses Pieces Bag" -> Beef Ravioli in Tomato & Meat Sauce (0.023529411764705882)
# Reeses Pieces Bag" -> Large Grade AA Organic Eggs (0.011764705882352941)
# Reeses Pieces Bag" -> Creamy Root Beer Natural Cane Soda (0.011764705882352941)
# Sesame Ginger Marinade -> Extra Long Asparagus Spears (0.125)
# Sesame Ginger Marinade -> Steamfresh Sweet Peas (0.125)
# Sesame Ginger Marinade -> Chicken Flavor Ramen Noodle Soup (0.125)
# Sesame Ginger Marinade -> Pure Cane Sugar Cubes (0.125)
# Sesame Ginger Marinade -> Baby Kale Mix (0.125)
# Organic Life Vitamins Raspberry Cranberry Flavor Liquid -> 100% Recycled 2 Ply Jumbo Paper Towel Roll (0.3333333333333333)
# Organic Life Vitamins Raspberry Cranberry Flavor Liquid -> Organic Garlic Cilantro Salsa (0.3333333333333333)
# Organic Life Vitamins Raspberry Cranberry Flavor Liquid -> Organic Apple Cider Vinegar & Honey All Natural Drink (0.3333333333333333)
# Organic Life Vitamins Raspberry Cranberry Flavor Liquid -> Vitamin C Rejuvenating Oil-Free Moisturizer (0.3333333333333333)
# Organic Life Vitamins Raspberry Cranberry Flavor Liquid -> Organic Tomato Cluster (0.3333333333333333)
# BBQ Ranch Salad Kit -> Soft & Smooth Whole Grain White Bread (0.05263157894736842)
# Pure Spanish Saffron -> Reduced Fat 2% Milk (0.014285714285714285)
# Mini Muffins -> Organic SprouTofu Super Firm Tofu (0.00510204081632653)
# Mini Muffins -> Creamy Almond Butter (0.01020408163265306)
# Mini Muffins -> Ponzu Sauce (0.00510204081632653)
# Mini Muffins -> Organic Wheat Square Crackers (0.015306122448979591)
# Mini Muffins -> Organic Gluten Free Dude Ranch Multigrain Snack Chips (0.00510204081632653)
# Organic Capellini -> Organic Orange Juice With Calcium & Vitamin D (0.001783166904422254)
# Organic Capellini -> Organic Green Cabbage (0.007845934379457917)
# Organic Capellini -> Lactose Free Yogurt Plain (0.0007132667617689016)
# Organic Capellini -> Turmeric Root (0.001783166904422254)
# Organic Capellini -> Organic Original Unsweetened Sprouted Rice Drink (0.0003566333808844508)
# Grain Free Cassava & Chia Tortillas -> Organic Quinoa Fusilli Pasta Gluten Free (0.0070921985815602835)
# Grain Free Cassava & Chia Tortillas -> Organic Whole Grassmilk Milk (0.0070921985815602835)
# Grain Free Cassava & Chia Tortillas -> 100% Raw Coconut Water (0.0070921985815602835)
# Grain Free Cassava & Chia Tortillas -> Muffin & Cake Mix + Almond Flour + Chocolate (0.0070921985815602835)
# Grain Free Cassava & Chia Tortillas -> Free & Clear Size 4 Baby Diapers (0.0070921985815602835)
# Beef Demi-Glace -> White Cannellini Kidney Beans (0.0625)
# Beef Demi-Glace -> Organic Large Grade A Brown Eggs (0.0625)
# Beef Demi-Glace -> Original Worcestershire Sauce (0.0625)
# Beef Demi-Glace -> Classic Beef Stock (0.125)
# Beef Demi-Glace -> Glace De Viande Veal & Beef Stock (0.0625)
# Ranch Style Beef & Vegetable Recipe Dog Treats -> Fine Granulated Sugar (0.16666666666666666)
# Ranch Style Beef & Vegetable Recipe Dog Treats -> Grade A Organic Large Brown Eggs (0.16666666666666666)
# Ranch Style Beef & Vegetable Recipe Dog Treats -> Organic Vanilla Soymilk (0.16666666666666666)
# Ranch Style Beef & Vegetable Recipe Dog Treats -> The Greek Burrito (0.16666666666666666)
# Ranch Style Beef & Vegetable Recipe Dog Treats -> Wild Blueberry Fruit Spread (0.16666666666666666)
# Vegetarian Roast -> 100% Whole Wheat English Muffin 6 Ct (0.007751937984496124)
# Vegetarian Roast -> Hash Browns Root Vegetable (0.007751937984496124)
# Vegetarian Roast -> Brownberry Natural Wheat Bread (0.007751937984496124)
# Vegetarian Roast -> Ancient Grain Original Granola (0.007751937984496124)
# Vegetarian Roast -> Gluten Free Lemonzest Nutrition bar (0.007751937984496124)
# Peaches Large -> Mineral-Based SPF 50 Baby Sunscreen Lotion Tube (0.00038138825324180017)
# Peaches Large -> Flour Tortillas Soft Taco (0.002288329519450801)
# Peaches Large -> Hass Avocados (0.005339435545385202)
# Peaches Large -> Long Grain & Wild Rice (0.00038138825324180017)
# Peaches Large -> Mild Kimchi (0.0007627765064836003)
# Geneva Cookies -> Organic Dark Chocolate Almond Granola Cereal (0.01282051282051282)
# Geneva Cookies -> Vanilla Soy Creamer (0.01282051282051282)
# Tortilla Crusted Tilapia -> Large Grapefruit (0.011363636363636364)
# Tortilla Crusted Tilapia -> Chicken with Peanut Sauce (0.011363636363636364)
# Tortilla Crusted Tilapia -> ProteinPLUS Multigrain Penne Pasta (0.011363636363636364)
# Grain Free Soft Dog Food -> Energy Drink (0.03225806451612903)
# Grain Free Soft Dog Food -> Greek Whips Chocolate Cherry (0.03225806451612903)
# Grain Free Soft Dog Food -> Shredded Sharp Cheddar Cheese (0.03225806451612903)
# Grain Free Soft Dog Food -> Ultra Original Scent Dishwashing Liquid (0.03225806451612903)
# Grain Free Soft Dog Food -> Original Potato Crisps (0.06451612903225806)
# Naproxen Pain Reliever/Fever Reducer Tablets -> Pain Reliever and Fever Reducer Caplets (0.023809523809523808)
# Naproxen Pain Reliever/Fever Reducer Tablets -> Multi-Grain English Muffins (0.023809523809523808)
# Naproxen Pain Reliever/Fever Reducer Tablets -> Apple Apple Applesauce On The Go Pouches (0.023809523809523808)
# Naproxen Pain Reliever/Fever Reducer Tablets -> Diced No Salt Added Tomatoes (0.023809523809523808)
# Naproxen Pain Reliever/Fever Reducer Tablets -> Calcium Carbonate/Antacid + Fruit Chews + Chewable Tablets (0.023809523809523808)
# All Purpose Baking Mix -> Texas Garlic Toast (0.05555555555555555)
# All Purpose Baking Mix -> Original Black Tea (0.05555555555555555)
# All Purpose Baking Mix -> Chicken Breast Nuggets + Dinosaur Shaped (0.05555555555555555)
# All Purpose Baking Mix -> Organic Half & Half (0.05555555555555555)
# All Purpose Baking Mix -> RapidRise Yeast (0.05555555555555555)
# Chocolate Fudge High Protein Bar -> Mild Italian Chicken Sausage (0.001183431952662722)
# Chocolate Fudge High Protein Bar -> Blueberry Protein Shake (0.0035502958579881655)
# Chocolate Fudge High Protein Bar -> Vanilla Skyr Style Yogurt (0.005917159763313609)
# Chocolate Fudge High Protein Bar -> Core Gluten Free Mint Chocolate Bar (0.001183431952662722)
# Chocolate Fudge High Protein Bar -> Lemon Cake Ice Cream (0.0035502958579881655)
# Hand Soap + Liquid + Parsley Scent -> Macaroni & Cheese (0.008620689655172414)
# Hand Soap + Liquid + Parsley Scent -> Organic Blues Bread with Blue Cornmeal Crust (0.008620689655172414)
# Hand Soap + Liquid + Parsley Scent -> Natural Free & Clear Dish Liquid (0.01293103448275862)
# Hand Soap + Liquid + Parsley Scent -> Organic Edamame (0.004310344827586207)
# Hand Soap + Liquid + Parsley Scent -> Savoy Cabbage (0.004310344827586207)
# Mesquite BBQ Kettle Potato CHips -> Red Velvet Cake Mix (0.1)
# Mesquite BBQ Kettle Potato CHips -> Raspberries (0.1)
# Mesquite BBQ Kettle Potato CHips -> Newman-Os + Chocolate Creme filled Chocolate Cookies (0.3)
# Mesquite BBQ Kettle Potato CHips -> Tartar Sauce (0.1)
# Mesquite BBQ Kettle Potato CHips -> Organic Bagged Mini Milk Peanut Butter (0.2)
# CPU times: user 712 ms, sys: 236 ms, total: 948 ms
# Wall time: 1h 9min 45s
